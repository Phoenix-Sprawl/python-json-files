# %%
import json
inventory_list = [
  {"title": "The Alchemist", "author": "Paulo Coelho", "price": 12.99, "in_stock": True},
  {"title": "1984", "author": "George Orwell", "price": 9.99, "in_stock": True}
]

# %%
with open ("inventory.json","w") as f:
  json.dump(inventory_list,f)

# %%
new_book = {"title": "Atomic Habits","author": "James Clear", "price": 14.99, "in_stock":True}

# %%
#Task 1 - Read the inventory

with open ("inventory.json","r") as f:
  inventory = json.load(f)
count = 0
for books in inventory:
    count += 1
print(f"Total number of books currently in the inventory: {count}")
# Out:
# Total number of books currently in the inventory: 2

# %%
#Task 2 - Update and save

#Append new_book to the inventory_list and then write the updated list back to inventory.json with an indentation of 4 spaces.
inventory_list.append(new_book)

# %%
print(inventory_list)
# Out:
# [{'title': 'The Alchemist', 'author': 'Paulo Coelho', 'price': 12.99, 'in_stock': True}, {'title': '1984', 'author': 'George Orwell', 'price': 9.99, 'in_stock': True}, {'title': 'Atomic Habits', 'author': 'James Clear', 'price': 14.99, 'in_stock': True}]

# %%
with open("inventory.json","w") as f:
  json.dump(inventory_list,f,indent=4)

# %%
#Task 3 - Display the inventory
with open("inventory.json","r") as f:
  inventory = json.load(f)

for book in inventory:
  print(f"Title: {book['title']} | Author: {book['author']} | Price: ${book['price']}")
# Out:
# Title: The Alchemist | Author: Paulo Coelho | Price: $12.99
# Title: 1984 | Author: George Orwell | Price: $9.99
# Title: Atomic Habits | Author: James Clear | Price: $14.99
